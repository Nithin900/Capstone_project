# %%
pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (2.1.1)
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: seaborn in /home/codespace/.local/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.12/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy

# %%
pip install dtale
# Out:
# Collecting dtale
#   Downloading dtale-3.14.1-py2.py3-none-any.whl.metadata (17 kB)
# Collecting dash-colorscales (from dtale)
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dash-daq (from dtale)
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 7.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Flask-Compress (from dtale)
#   Downloading Flask_Compress-1.17-py3-none-any.whl.metadata (8.8 kB)
# Collecting future>=0.14.0 (from dtale)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting kaleido (from dtale)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Collecting missingno (from dtale)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (from dtale) (2.2.2)
# Collecting squarify (from dtale)
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Collecting strsimpy (from dtale)
#   Downloading strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (1.16.0)
# Collecting xlrd (from dtale)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (4.12.3)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (2024.8.30)
# Collecting flask-ngrok (from dtale)
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl.metadata (1.8 kB)
# Collecting lz4 (from dtale)
#   Downloading lz4-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: cycler in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (0.12.1)
# Collecting dash-bootstrap-components<=1.3.1 (from dtale)
#   Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting dash (from dtale)
#   Downloading dash-2.18.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: seaborn in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (0.13.2)
# Collecting werkzeug (from dtale)
#   Downloading werkzeug-3.0.4-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: scikit-learn in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (1.5.2)
# Collecting statsmodels (from dtale)
#   Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: networkx in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (3.2.1)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (2.1.1)
# Collecting openpyxl!=3.2.0b1 (from dtale)
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting xarray (from dtale)
#   Downloading xarray-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy!=1.12.0rc1,!=1.14.0,!=1.14.0rc1,!=1.14.0rc2 in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (1.14.1)
# Collecting et-xmlfile (from dtale)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: plotly in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (5.24.1)
# Collecting Flask<2.3 (from dtale)
#   Downloading Flask-2.2.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (2.32.3)
# Collecting itsdangerous (from dtale)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: contourpy in /home/codespace/.local/lib/python3.12/site-packages (from dtale) (1.3.0)
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (from dtale) (3.8.4)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.6)
# Collecting dash-html-components==2.0.0 (from dash->dtale)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash->dtale)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash->dtale)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash->dtale)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/codespace/.local/lib/python3.12/site-packages (from dash->dtale) (4.9.0)
# Collecting retrying (from dash->dtale)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /home/codespace/.local/lib/python3.12/site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from dash->dtale) (75.1.0)
# Requirement already satisfied: Jinja2>=3.0 in /home/codespace/.local/lib/python3.12/site-packages (from Flask<2.3->dtale) (3.1.4)
# Collecting click>=8.0 (from Flask<2.3->dtale)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from plotly->dtale) (9.0.0)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from plotly->dtale) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/codespace/.local/lib/python3.12/site-packages (from werkzeug->dtale) (2.1.5)
# Collecting brotli (from Flask-Compress->dtale)
#   Downloading Brotli-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting zstandard (from Flask-Compress->dtale)
#   Downloading zstandard-0.23.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->dtale) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->dtale) (1.4.7)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->dtale) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->dtale) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->dtale) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->dtale) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->dtale) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->dtale) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->dtale) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn->dtale) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from scikit-learn->dtale) (3.5.0)
# Collecting patsy>=0.5.6 (from statsmodels->dtale)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting zipp>=3.20 (from importlib-metadata->dash->dtale)
#   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Downloading dtale-3.14.1-py2.py3-none-any.whl (14.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 66.8 MB/s eta 0:00:00:00:01
# Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl (219 kB)
# Downloading dash-2.18.1-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 58.3 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading werkzeug-3.0.4-py3-none-any.whl (227 kB)
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Downloading Flask_Compress-1.17-py3-none-any.whl (8.7 kB)
# Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 75.7 MB/s eta 0:00:00:00:0100:01
# Downloading lz4-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.6 MB/s eta 0:00:00
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 76.6 MB/s eta 0:00:00
# Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Downloading xarray-2024.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.8 MB/s eta 0:00:00
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Downloading Brotli-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 22.8 MB/s eta 0:00:00
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading zstandard-0.23.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 61.9 MB/s eta 0:00:00
# Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Building wheels for collected packages: dash-colorscales, dash-daq
#   Building wheel for dash-colorscales (pyproject.toml) ... done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62569 sha256=a1853490f11a237eeecc7e79d1e34c00983415f1f4f476c5a0fda2060defb6d4
#   Stored in directory: /home/codespace/.cache/pip/wheels/84/23/44/63e5ef837d475b972c17c0a841473421c954069fdd7ba062ad
#   Building wheel for dash-daq (pyproject.toml) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669692 sha256=839a73b35e0a8cfc3b1d0fc5f1344aac53fee05f7a84343c72580f903ffe0b3d
#   Stored in directory: /home/codespace/.cache/pip/wheels/40/89/1a/4435006b003f97da22dbcad819d26f957dad9d54a1678876fd
# Successfully built dash-colorscales dash-daq
# Installing collected packages: strsimpy, squarify, kaleido, dash-table, dash-html-components, dash-core-components, dash-colorscales, brotli, zstandard, zipp, xlrd, werkzeug, retrying, patsy, lz4, itsdangerous, future, et-xmlfile, click, openpyxl, importlib-metadata, Flask, xarray, statsmodels, flask-ngrok, Flask-Compress, dash, missingno, dash-daq, dash-bootstrap-components, dtale
#   WARNING: The scripts futurize and pasteurize are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script flask is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts dash-generate-components, dash-update-components and renderer are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts dtale and dtale-streamlit are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed Flask-2.2.5 Flask-Compress-1.17 brotli-1.1.0 click-8.1.7 dash-2.18.1 dash-bootstrap-components-1.3.1 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-3.14.1 et-xmlfile-1.1.0 flask-ngrok-0.0.25 future-1.0.0 importlib-metadata-8.5.0 itsdangerous-2.2.0 kaleido-0.2.1 lz4-4.3.3 missingno-0.5.2 openpyxl-3.1.5 patsy-0.5.6 retrying-1.3.4 squarify-0.4.4 statsmodels-0.14.4 strsimpy-0.2.1 werkzeug-3.0.4 xarray-2024.9.0 xlrd-2.0.1 zipp-3.20.2 zstandard-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pv_care_hos=pd.read_csv(r"/workspaces/codespaces-jupyter/Payment_and_Value_of_Care-Hospital.csv")
data.head()
# Out:
#    Facility ID                    Facility Name                     Address  \
# 0        10001  SOUTHEAST HEALTH MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST HEALTH MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST HEALTH MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 3        10001  SOUTHEAST HEALTH MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 4        10005         MARSHALL MEDICAL CENTERS  2505 U S HIGHWAY 431 NORTH
#
#   City/Town State  ZIP Code County/Parish Telephone Number Payment Measure ID  \
# 0    DOTHAN    AL     36301       HOUSTON   (334) 793-8701        PAYM_30_AMI
# 1    DOTHAN    AL     36301       HOUSTON   (334) 793-8701         PAYM_30_HF
# 2    DOTHAN    AL     36301       HOUSTON   (334) 793-8701         PAYM_30_PN
# 3    DOTHAN    AL     36301       HOUSTON   (334) 793-8701   PAYM_90_HIP_KNEE
# 4      BOAZ    AL     35957      MARSHALL   (256) 593-8310        PAYM_30_AMI
#
#                         Payment Measure Name  ...  Payment Lower Estimate  \
# 0          Payment for heart attack patients  ...  $28,502        $26,229
# 1         Payment for heart failure patients  ...  $20,602        $19,572
# 2             Payment for pneumonia patients  ...  $22,404        $21,247
# 3  Payment for hip/knee replacement patients  ...  $22,819        $20,082
# 4          Payment for heart attack patients  ...  $26,561        $22,721
#
#   Higher Estimate Payment Footnote Value of Care Display ID  \
# 0         $30,939              NaN         MORT_PAYM_30_AMI
# 1         $21,713              NaN          MORT_PAYM_30_HF
# 2         $23,627              NaN          MORT_PAYM_30_PN
# 3         $26,007              NaN    COMP_PAYM_90_HIP_KNEE
# 4         $30,858              NaN         MORT_PAYM_30_AMI
#
#            Value of Care Display Name  \
# 0  Value of Care Heart Attack measure
# 1  Value of Care Heart Failure measur
# 2     Value of Care Pneumonia measure
# 3  Value of Care hip/knee replacement
# 4  Value of Care Heart Attack measure
#
#                       Value of Care Category Value of Care Footnote  \
# 0      Average Mortality and Average Payment                    NaN
# 1      Average Mortality and Average Payment                    NaN
# 2       Average Mortality and Higher Payment                    NaN
# 3  Average Complications and Average Payment                    NaN
# 4      Average Mortality and Average Payment                    NaN
#
#    Start Date    End Date
# 0  07/01/2020  06/30/2023
# 1  07/01/2020  06/30/2023
# 2  07/01/2020  06/30/2023
# 3  07/01/2020  03/31/2023
# 4  07/01/2020  06/30/2023
#
# [5 rows x 22 columns]

# %%
pv_care_hos.columns
# Out:
# Index(['Facility ID', 'Facility Name', 'Address', 'City/Town', 'State',
#        'ZIP Code', 'County/Parish', 'Telephone Number', 'Payment Measure ID',
#        'Payment Measure Name', 'Payment Category', 'Denominator', 'Payment',
#        'Lower Estimate', 'Higher Estimate', 'Payment Footnote',
#        'Value of Care Display ID', 'Value of Care Display Name',
#        'Value of Care Category', 'Value of Care Footnote', 'Start Date',
#        'End Date'],
#       dtype='object')

# %%
pv_care_hos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18500 entries, 0 to 18499
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Facility ID                 18500 non-null  int64
#  1   Facility Name               18500 non-null  object
#  2   Address                     18500 non-null  object
#  3   City/Town                   18500 non-null  object
#  4   State                       18500 non-null  object
#  5   ZIP Code                    18500 non-null  int64
#  6   County/Parish               18500 non-null  object
#  7   Telephone Number            18500 non-null  object
#  8   Payment Measure ID          18500 non-null  object
#  9   Payment Measure Name        18500 non-null  object
#  10  Payment Category            18500 non-null  object
#  11  Denominator                 18500 non-null  object
#  12  Payment                     18500 non-null  object
#  13  Lower Estimate              18500 non-null  object
#  14  Higher Estimate             18500 non-null  object
#  15  Payment Footnote            8612 non-null   object
#  16  Value of Care Display ID    18500 non-null  object
#  17  Value of Care Display Name  18500 non-null  object
#  18  Value of Care Category      18500 non-null  object
#  19  Value of Care Footnote      8510 non-null   float64
#  20  Start Date                  18500 non-null  object
#  21  End Date                    18500 non-null  object
# dtypes: float64(1), int64(2), object(19)
# memory usage: 3.1+ MB

# %%
pv_care_hos.isna().sum()
# Out:
# Facility ID                      0
# Facility Name                    0
# Address                          0
# City/Town                        0
# State                            0
# ZIP Code                         0
# County/Parish                    0
# Telephone Number                 0
# Payment Measure ID               0
# Payment Measure Name             0
# Payment Category                 0
# Denominator                      0
# Payment                          0
# Lower Estimate                   0
# Higher Estimate                  0
# Payment Footnote              9888
# Value of Care Display ID         0
# Value of Care Display Name       0
# Value of Care Category           0
# Value of Care Footnote        9990
# Start Date                       0
# End Date                         0
# dtype: int64

# %%
#to find unique values
pv_care_hos.Payment.unique()
# Out:
# array(['$28,502', '$20,602', '$22,404', ..., '$19,087', '$21,538',
#        '$22,031'], dtype=object)

# %%
#Payment	Lower Estimate	Higher Estimate
pv_care_hos['Payment'] = pv_care_hos['Payment'].str.replace('$', '').str.replace(',', '')
pv_care_hos['Lower Estimate'] = pv_care_hos['Lower Estimate'].str.replace('$', '').str.replace(',', '')
pv_care_hos['PaymHigher Estimateent'] = pv_care_hos['Higher Estimate'].str.replace('$', '').str.replace(',', '')

# pv_care_hos['Payment'] = pv_care_hos['Payment'].astype(int)
# pv_care_hos['Lower Estimate'] = pv_care_hos['Lower Estimate'].astype(int)
# pv_care_hos['Higher Estimate'] = pv_care_hos['Higher Estimate'].astype(int)
